# %% [markdown]
# <a href="https://colab.research.google.com/github/yichousun/Winter2021_CS249_GNN/blob/main/Paper_Presentation/Expressive_Power/HighOrderGNN/Provably_Powerful_Graph_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook for Provably Powerful Graph Networks
#
# Here is the [code](https://github.com/hadarser/ProvablyPowerfulGraphNetworks) for the paper [Provable Powerful Graph Networks](https://arxiv.org/pdf/1905.11136.pdf) and we verify it on google CoLab
#
# Since there would be lots of output for the training cell, use the Table of Contents to skip the massive output.

# %% [markdown]
# ## Prerequisites
# - Check out that Edit > Notebook Settings > Hardware accelerator is GPU
# - The cell below should be run **only once**, otherwise it might mess up the run time. Select Runtime > Factory Reset runtime if the runtime is messed up
# - For faster computation, we change the epoches to 1 using `! sed -i 's/self.config.num_epochs/1/g' trainers/trainer.py`. Use `git reset --hard HEAD` if you want to get the full result.

# %%
# %tensorflow_version 1.x
! git clone https://github.com/hadarser/ProvablyPowerfulGraphNetworks.git
% cd ProvablyPowerfulGraphNetworks/
! python3 utils/get_data.py
! sed -i 's/self.config.num_epochs/1/g' trainers/trainer.py
# Out:
# TensorFlow 1.x selected.
# Cloning into 'ProvablyPowerfulGraphNetworks'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 55 (delta 16), reused 29 (delta 1), pack-reused 0
# Unpacking objects: 100% (55/55), done.
# /content/ProvablyPowerfulGraphNetworks
# ...
# tcmalloc: large alloc 2066210816 bytes == 0x55b2d8ad0000 @  0x7ff04f7c81e7 0x55b25a161f48 0x55b25a12c9c7 0x55b25a12e9c0 0x55b25a12fe8d 0x55b25a22199d 0x55b25a1a3fe9 0x55b25a13169a 0x55b25a19fc9e 0x55b25a19eb0e 0x55b25a13177a 0x55b25a19fc9e 0x55b25a13169a 0x55b25a19fa45 0x55b25a13169a 0x55b25a19fa45 0x55b25a13169a 0x55b25a19fa45 0x55b25a19eb0e 0x55b25a19e813 0x55b25a268592 0x55b25a26890d 0x55b25a2687b6 0x55b25a240103 0x55b25a23fdac 0x7ff04e5b2bf7 0x55b25a23fc8a

# %% [markdown]
# ## Experiments on classification tasks
#
# Here is the 8 datasets for the classification tasks. 7 of them run successfully on Colab, but for proteins, it exhausts the GPU memory and you may need a more powerful GPU to run that.

# %%
! python3 main_scripts/main_10fold_experiment.py --config=configs/10fold_config.json --dataset_name=NCI1
# Out:
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:37: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# lr = 0.0001
# decay = 0.75
# {'block_features': [400, 400, 400], 'depth_of_mlp': 2, 'new_suffix': True}
# Experiment num = 1
# Fold num = 1
# /content/ProvablyPowerfulGraphNetworks/data_loader/data_helper.py:36: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   graphs = np.array(graphs)
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:51: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:54: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# ...

# %%
! python3 main_scripts/main_10fold_experiment.py --config=configs/10fold_config.json --dataset_name=COLLAB
# Out:
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:37: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# lr = 0.0001
# decay = 0.5
# {'block_features': [400, 400, 400], 'depth_of_mlp': 2, 'new_suffix': True}
# Experiment num = 1
# Fold num = 1
# /content/ProvablyPowerfulGraphNetworks/data_loader/data_helper.py:36: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   graphs = np.array(graphs)
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:51: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:54: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# ...

# %%
! python3 main_scripts/main_10fold_experiment.py --config=configs/10fold_config.json --dataset_name=NCI109
# Out:
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:37: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# lr = 0.0001
# decay = 0.75
# {'block_features': [400, 400, 400], 'depth_of_mlp': 2, 'new_suffix': True}
# Experiment num = 1
# Fold num = 1
# /content/ProvablyPowerfulGraphNetworks/data_loader/data_helper.py:36: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   graphs = np.array(graphs)
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:51: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:54: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# ...

# %%
! python3 main_scripts/main_10fold_experiment.py --config=configs/10fold_config.json --dataset_name=MUTAG
# Out:
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:37: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# lr = 0.0001
# decay = 1.0
# {'block_features': [400, 400, 400], 'depth_of_mlp': 2, 'new_suffix': True}
# Experiment num = 1
# Fold num = 1
# /content/ProvablyPowerfulGraphNetworks/data_loader/data_helper.py:36: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   graphs = np.array(graphs)
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:51: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:54: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# ...

# %%
! python3 main_scripts/main_10fold_experiment.py --config=configs/10fold_config.json --dataset_name=PTC
# Out:
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:37: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# lr = 0.0001
# decay = 1.0
# {'block_features': [400, 400, 400], 'depth_of_mlp': 2, 'new_suffix': True}
# Experiment num = 1
# Fold num = 1
# /content/ProvablyPowerfulGraphNetworks/data_loader/data_helper.py:36: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   graphs = np.array(graphs)
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:51: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:54: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# ...

# %%
! python3 main_scripts/main_10fold_experiment.py --config=configs/10fold_config.json --dataset_name=IMDBBINARY
# Out:
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:37: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# lr = 5e-05
# decay = 0.5
# {'block_features': [400, 400, 400], 'depth_of_mlp': 2, 'new_suffix': True}
# Experiment num = 1
# Fold num = 1
# /content/ProvablyPowerfulGraphNetworks/data_loader/data_helper.py:36: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   graphs = np.array(graphs)
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:51: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:54: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# ...

# %%
! python3 main_scripts/main_10fold_experiment.py --config=configs/10fold_config.json --dataset_name=IMDBMULTI
# Out:
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:37: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# lr = 0.0001
# decay = 0.75
# {'block_features': [400, 400, 400], 'depth_of_mlp': 2, 'new_suffix': True}
# Experiment num = 1
# Fold num = 1
# /content/ProvablyPowerfulGraphNetworks/data_loader/data_helper.py:36: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   graphs = np.array(graphs)
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:51: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:54: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# ...

# %%
# Running this will exhaust the GPU memory on Colab, you may need a more powerful GPU to run this
! python3 main_scripts/main_10fold_experiment.py --config=configs/10fold_config.json --dataset_name=PROTEINS
# Out:
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:37: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# lr = 0.001
# decay = 0.5
# {'block_features': [400, 400, 400], 'depth_of_mlp': 2, 'new_suffix': True}
# Experiment num = 1
# Fold num = 1
# /content/ProvablyPowerfulGraphNetworks/data_loader/data_helper.py:36: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   graphs = np.array(graphs)
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:51: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From main_scripts/main_10fold_experiment.py:54: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# ...

# %% [markdown]
# ## Experiments on regression task
#
# Here is the experiment on regression task (i.e. QM9 dataset). Running this experiment would exhaust the memory (12GB) on Colab. You may need a more powerful server to run that.

# %%
# Running this will exhaust the memory on Colab
! python3 main_scripts/main_qm9_experiment.py --config=configs/qm9_config.json --dataset_name=QM9
# Out:
# WARNING:tensorflow:From main_scripts/main_qm9_experiment.py:37: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# lr = 0.0001
# decay = 0.8
# {'block_features': [400, 400, 400], 'depth_of_mlp': 2, 'new_suffix': False}
# /content/ProvablyPowerfulGraphNetworks/data_loader/data_helper.py:84: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   graphs = np.array(graphs)
# WARNING:tensorflow:From main_scripts/main_qm9_experiment.py:50: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From main_scripts/main_qm9_experiment.py:53: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# ...
